# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# Q1> Display “Hello World” and your name.
# Hello World
print("Hello World")
print("Tarun muddana")
# Out:
# Hello World
# Name: Bhanu Prasad

# %%
# Q2> Perform arithmetic operations between two user inputs.
# Arithmetic Operations
a = int(input("Enter a: "))
b = int(input("Enter b: "))
print("Add:", a+b)
print("Sub:", a-b)
print("Mul:", a*b)
print("Div:", a/b)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[3], line 3
#       1 # Q2> Perform arithmetic operations between two user inputs.
#       2 # Arithmetic Operations
# ----> 3 a = int(input("Enter a: "))
#       4 b = int(input("Enter b: "))
#       5 print("Add:", a+b)
#
# ValueError: invalid literal for int() with base 10: ''

# %%
# 3> Load a dataset (CSV file) using pandas
# Load Dataset
import sklearn.datasets as datasets
df = pd.read_csv('https://raw.githubusercontent.com/mwaskom/seaborn-data/master/iris.csv')

# %%
# 4> • Display first 5 rows using .head()
# Data Exploration
print(df.head())
print(df.info())
print(df.describe())
# Out:
#    sepal_length  sepal_width  petal_length  petal_width species
# 0           5.1          3.5           1.4          0.2  setosa
# 1           4.9          3.0           1.4          0.2  setosa
# 2           4.7          3.2           1.3          0.2  setosa
# 3           4.6          3.1           1.5          0.2  setosa
# 4           5.0          3.6           1.4          0.2  setosa
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 150 entries, 0 to 149
# Data columns (total 5 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   sepal_length  150 non-null    float64
#  1   sepal_width   150 non-null    float64
#  2   petal_length  150 non-null    float64
#  3   petal_width   150 non-null    float64
#  4   species       150 non-null    object
# dtypes: float64(4), object(1)
# memory usage: 6.0+ KB
# None
#        sepal_length  sepal_width  petal_length  petal_width
# ...

# %%
# 5> • Customize plots with titles, labels, and legends.
# Matplotlib Plot
plt.scatter(df.iloc[:,0], df.iloc[:,1])
plt.title("Scatter Plot")
plt.xlabel("X")
plt.ylabel("Y")
plt.show()
# Seaborn Plot
sns.scatterplot(x=df.iloc[:,0], y=df.iloc[:,1])
plt.show()

# %%
# Post-Lab:
# 1. Write a program to calculate the sum of digits of a given number.
# 2. Write a program to print a multiplication table up to 10 for auser-entered number.
# 3. Create a pie chart showing distribution of categorical data.
# 4. Compare the performance of different data loading methods inpandas.
# 5. Implement error handling for file operations.
import pandas as pd
import matplotlib.pyplot as plt
# Sum of digits
n = int(input("Enter number: "))
s = 0
while n>0:
 s += n%10
 n//=10
print("Sum:",s)
# Multiplication table
num = int(input("Enter number: "))
for i in range(1,11):
 print(num,"x",i,"=",num*i)
# Pie chart
labels = ['A','B','C']
values = [30,40,30]
plt.pie(values, labels=labels, autopct='%1.1f%%')
plt.show()
# Compare loading methods
df1 = pd.read_csv("train_data.csv")
print("CSV Loaded")
# Error handling
try:
 df = pd.read_csv("train_data.csv")
 print(df.head())
except:
 print("File not found")
