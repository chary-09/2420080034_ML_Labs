# %%
import numpy as np
from sklearn.svm import SVC
from sklearn.datasets import make_moons
from sklearn.preprocessing import StandardScaler

# %%
X_moons, y_moons = make_moons(n_samples=300, noise=0.2, random_state=42)

X_moons = StandardScaler().fit_transform(X_moons)

# %%
svm_linear = SVC(kernel='linear')
svm_linear.fit(X_moons, y_moons)

svm_linear
# Out:
# SVC(kernel='linear')

# %%
svm_poly2 = SVC(kernel='poly', degree=2)
svm_poly2.fit(X_moons, y_moons)

svm_poly2
# Out:
# SVC(degree=2, kernel='poly')

# %%
svm_poly3 = SVC(kernel='poly', degree=3)
svm_poly3.fit(X_moons, y_moons)

svm_poly3
# Out:
# SVC(kernel='poly')

# %%
svm_poly4 = SVC(kernel='poly', degree=4)
svm_poly4.fit(X_moons, y_moons)

svm_poly4
# Out:
# SVC(degree=4, kernel='poly')

# %%
svm_rbf1 = SVC(kernel='rbf', gamma=0.5)
svm_rbf1.fit(X_moons, y_moons)

svm_rbf1
# Out:
# SVC(gamma=0.5)

# %%
svm_rbf2 = SVC(kernel='rbf', gamma=1)
svm_rbf2.fit(X_moons, y_moons)

svm_rbf2
# Out:
# SVC(gamma=1)

# %%
svm_rbf3 = SVC(kernel='rbf', gamma=5)
svm_rbf3.fit(X_moons, y_moons)

svm_rbf3
# Out:
# SVC(gamma=5)

# %%
svm_sigmoid = SVC(kernel='sigmoid')
svm_sigmoid.fit(X_moons, y_moons)

svm_sigmoid
# Out:
# SVC(kernel='sigmoid')

# %%
import numpy as np
import matplotlib.pyplot as plt
from sklearn.svm import SVC
from sklearn.datasets import make_moons, make_circles
from sklearn.preprocessing import StandardScaler

def plot_decision_boundary(model, X, y, title):

    plt.figure(figsize=(6,5))

    # Create mesh grid
    x_min, x_max = X[:,0].min()-1, X[:,0].max()+1
    y_min, y_max = X[:,1].min()-1, X[:,1].max()+1

    xx, yy = np.meshgrid(
        np.linspace(x_min, x_max, 300),
        np.linspace(y_min, y_max, 300)
    )

    # Predict grid points
    Z = model.predict(np.c_[xx.ravel(), yy.ravel()])
    Z = Z.reshape(xx.shape)

    # Plot boundary
    plt.contourf(xx, yy, Z, alpha=0.3)

    # Plot data points
    plt.scatter(X[:,0], X[:,1], c=y, edgecolors='k')

    # Highlight support vectors
    plt.scatter(
        model.support_vectors_[:,0],
        model.support_vectors_[:,1],
        s=120,
        facecolors='none',
        edgecolors='black',
        label="Support Vectors"
    )

    plt.title(title)
    plt.legend()
    plt.show()

# %% [markdown]
# # CIRCLES DATASET — BLUE BOX OUTPUTS

# %%
from sklearn.datasets import make_circles

X_circle, y_circle = make_circles(n_samples=300, noise=0.1, factor=0.5, random_state=42)

X_circle = StandardScaler().fit_transform(X_circle)

# %%
svm_linear = SVC(kernel='linear')
svm_linear.fit(X_circle, y_circle)

svm_linear
# Out:
# SVC(kernel='linear')

# %%
svm_poly2 = SVC(kernel='poly', degree=2)
svm_poly2.fit(X_circle, y_circle)

svm_poly2
# Out:
# SVC(degree=2, kernel='poly')

# %%
svm_poly3 = SVC(kernel='poly', degree=3)
svm_poly3.fit(X_circle, y_circle)

svm_poly3
# Out:
# SVC(kernel='poly')

# %%
svm_poly4 = SVC(kernel='poly', degree=4)
svm_poly4.fit(X_circle, y_circle)

svm_poly4
# Out:
# SVC(degree=4, kernel='poly')

# %%
svm_rbf1 = SVC(kernel='rbf', gamma=0.5)
svm_rbf1.fit(X_circle, y_circle)

svm_rbf1
# Out:
# SVC(gamma=0.5)

# %%
svm_rbf2 = SVC(kernel='rbf', gamma=1)
svm_rbf2.fit(X_circle, y_circle)

svm_rbf2
# Out:
# SVC(gamma=1)

# %%
svm_rbf3 = SVC(kernel='rbf', gamma=5)
svm_rbf3.fit(X_circle, y_circle)

svm_rbf3
# Out:
# SVC(gamma=5)

# %%
svm_sigmoid = SVC(kernel='sigmoid')
svm_sigmoid.fit(X_circle, y_circle)

svm_sigmoid
# Out:
# SVC(kernel='sigmoid')

# %% [markdown]
# # XOR DATASET — BLUE BOX OUTPUTS

# %%
np.random.seed(42)

X_xor = np.random.randn(300, 2)
y_xor = np.logical_xor(X_xor[:, 0] > 0, X_xor[:, 1] > 0)
y_xor = np.where(y_xor, 1, 0)

X_xor = StandardScaler().fit_transform(X_xor)

# %%
svm_linear = SVC(kernel='linear')
svm_linear.fit(X_xor, y_xor)

svm_linear
# Out:
# SVC(kernel='linear')

# %%
svm_poly2 = SVC(kernel='poly', degree=2)
svm_poly2.fit(X_xor, y_xor)

svm_poly2
# Out:
# SVC(degree=2, kernel='poly')

# %%
svm_poly3 = SVC(kernel='poly', degree=3)
svm_poly3.fit(X_xor, y_xor)

svm_poly3
# Out:
# SVC(kernel='poly')

# %%
svm_poly4 = SVC(kernel='poly', degree=4)
svm_poly4.fit(X_xor, y_xor)

svm_poly4
# Out:
# SVC(degree=4, kernel='poly')

# %%
svm_rbf1 = SVC(kernel='rbf', gamma=0.5)
svm_rbf1.fit(X_xor, y_xor)

svm_rbf1
# Out:
# SVC(gamma=0.5)

# %%
svm_rbf2 = SVC(kernel='rbf', gamma=1)
svm_rbf2.fit(X_xor, y_xor)

svm_rbf2
# Out:
# SVC(gamma=1)

# %%
svm_rbf3 = SVC(kernel='rbf', gamma=5)
svm_rbf3.fit(X_xor, y_xor)

svm_rbf3
# Out:
# SVC(gamma=5)

# %%
svm_sigmoid = SVC(kernel='sigmoid')
svm_sigmoid.fit(X_xor, y_xor)

svm_sigmoid
# Out:
# SVC(kernel='sigmoid')
